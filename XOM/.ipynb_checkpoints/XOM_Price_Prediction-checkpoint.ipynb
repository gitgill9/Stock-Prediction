# %%
#import all the basic libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the dataset in to dataframe
df = pd.read_csv('data/EOG.csv')

# %%
# Visually scan the data
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2016-05-09  78.209999  78.830002  77.040001  78.639999  73.266487
# 1  2016-05-10  78.769997  79.849998  78.709999  79.730003  74.281990
# 2  2016-05-11  79.379997  81.209999  78.220001  80.320000  74.831696
# 3  2016-05-12  81.389999  81.849998  79.550003  80.500000  74.999382
# 4  2016-05-13  80.209999  80.970001  78.599998  78.650002  73.275810
#
#       Volume      OBV  12_day_EMA  30_day_EMA  MACD    Change      Gain  \
# 0  3002700.0        0         NaN         NaN   NaN       NaN       NaN
# 1  4089700.0  4089700         NaN         NaN   NaN  1.090004  1.090004
# 2  3192000.0  7281700         NaN         NaN   NaN  0.589997  0.000000
# 3  2277400.0  9559100         NaN         NaN   NaN  0.180000  0.789024
# 4  3219100.0  6340000         NaN         NaN   NaN -1.849998  0.000000
#
#       Loss   Avg Gain  Avg Loss  RS  RSI
# 0       NaN       NaN       NaN NaN  NaN
# 1  0.000000       NaN       NaN NaN  NaN
# 2  0.000000       NaN       NaN NaN  NaN
# 3  0.000000       NaN       NaN NaN  NaN
# 4  1.849998       NaN       NaN NaN  NaN

# %%
#Rows and columns in the dataframe
df.shape
# Out:
# (1267, 18)

# %% [markdown]
# ## EDA

# %%
#Check for null values in the columns
df.isna().sum()
# Out:
# Date           8
# Open           8
# High           8
# Low            8
# Close          8
# Adj Close      8
# Volume         8
# OBV            0
# 12_day_EMA    11
# 30_day_EMA    29
# MACD          29
# Change         1
# Gain           1
# Loss           1
# Avg Gain      14
# Avg Loss      14
# RS            14
# RSI           14
# dtype: int64

# %% [markdown]
# The null values in the dataframe exist as some columns required previous days information. We will drop all the rows with null values.

# %%
#Drop the null values rows
df = df.dropna()

# %%
df.head()
# Out:
#           Date       Open       High        Low      Close  Adj Close  \
# 29  2016-06-20  82.330002  83.389999  81.809998  83.190002  77.505585
# 30  2016-06-21  82.989998  85.220001  82.830002  84.910004  79.108047
# 31  2016-06-22  84.900002  85.089996  83.430000  83.599998  77.887573
# 32  2016-06-23  84.760002  84.970001  83.970001  84.500000  78.726074
# 33  2016-06-24  81.580002  82.879997  80.809998  81.059998  75.521118
#
#        Volume      OBV  12_day_EMA  30_day_EMA      MACD    Change      Gain  \
# 29  3215000.0  2079700   82.414167   81.459667  0.954500  2.300003  0.846177
# 30  3539800.0  5619500   82.847500   81.668667  1.178833  1.720002  0.512596
# 31  2415600.0  3203900   83.041667   81.797667  1.244000 -1.310006  0.000000
# 32  2413200.0  5617100   82.965001   81.937000  1.028000  0.900002  1.749306
# 33  4942200.0   674900   82.606667   81.955667  0.651000 -3.440002  0.000000
#
#        Loss   Avg Gain  Avg Loss        RS        RSI
# 29  0.000000  0.291747  0.605715  0.481658  32.508021
# 30  0.000000  0.320805  0.562143  0.570681  36.333368
# 31  1.310006  0.320805  0.637143  0.503505  33.488732
# 32  0.000000  0.438200  0.581429  0.753660  42.976398
# 33  3.440002  0.408561  0.827144  0.493942  33.062980

# %%
df.isna().sum()
# Out:
# Date          0
# Open          0
# High          0
# Low           0
# Close         0
# Adj Close     0
# Volume        0
# OBV           0
# 12_day_EMA    0
# 30_day_EMA    0
# MACD          0
# Change        0
# Gain          0
# Loss          0
# Avg Gain      0
# Avg Loss      0
# RS            0
# RSI           0
# dtype: int64

# %% [markdown]
# Now our dataframe does not include any null values.

# %% [markdown]
# We will filter out the columns we need for modeling by creating a new dataframe.

# %%
# Final Dataframe
df_final = df[['Close', 'Volume','OBV','MACD','RSI']]

df_final.head()
# Out:
#         Close     Volume      OBV      MACD        RSI
# 29  83.190002  3215000.0  2079700  0.954500  32.508021
# 30  84.910004  3539800.0  5619500  1.178833  36.333368
# 31  83.599998  2415600.0  3203900  1.244000  33.488732
# 32  84.500000  2413200.0  5617100  1.028000  42.976398
# 33  81.059998  4942200.0   674900  0.651000  33.062980

# %% [markdown]
# ---

# %% [markdown]
# ## Visualization

# %%
plt.figure(figsize = (10,7))
plt.plot( df["Close"])
plt.xlabel("Time (Days)")
plt.ylabel("Close Price")
plt.title("EOG Close Price")
plt.show()

# %%
plt.figure(figsize= (10,7))
plt.plot( df['OBV'], color = 'Orange')
plt.xlabel("Time (Days)")
plt.ylabel("Volume")
plt.title("EOG OBV")
plt.show()

# %%
plt.figure(figsize= (10,7))
plt.plot( df['MACD'], color = 'Purple')
plt.xlabel("Time (Days)")
plt.ylabel("MACD")
plt.title("EOG MACD")
plt.show()

# %%
plt.figure(figsize= (10,7))
plt.plot( df['RSI'], color = 'Green')
plt.xlabel("Time (Days)")
plt.ylabel("RSI")
plt.title("EOG RSI")
plt.show()

# %% [markdown]
# We can see every indicator behave differently to price change. We can deduce that their is no correlation thee. Let's check its correlation by plotting each against one another.

# %%
sns.pairplot(df_final)

# %% [markdown]
# ### Correlation Matrix

# %%
# Compute the correlation matrix
corr = df_final.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap 
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,annot= True,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# From the above visuals it is clear that there is hardly any correlation between the technical indicators.

# %% [markdown]
# ---

# %% [markdown]
# ## **LSTM Modeling**

# %% [markdown]
# ### Set the Training set

# %%
#Selecting first 1000 values to train the dataset
training_set = df_final.iloc[:1000].values

# %%
training_set
# Out:
# array([[ 8.31900020e+01,  3.21500000e+06,  2.07970000e+06,
#          9.54499700e-01,  3.25080214e+01],
#        [ 8.49100040e+01,  3.53980000e+06,  5.61950000e+06,
#          1.17883328e+00,  3.63333681e+01],
#        [ 8.35999980e+01,  2.41560000e+06,  3.20390000e+06,
#          1.24400020e+00,  3.34887325e+01],
#        ...,
#        [ 5.93100010e+01,  6.32720000e+06, -2.66235000e+07,
#          3.45166667e+00,  8.12757249e+01],
#        [ 6.21100010e+01,  6.07510000e+06, -2.05484000e+07,
#          3.61499992e+00,  7.96208634e+01],
#        [ 5.94700010e+01,  6.33690000e+06, -2.68853000e+07,
#          3.71316667e+00,  7.69087716e+01]])

# %% [markdown]
# ### Feature Scaling

# %% [markdown]
# **Scaling the dataset:** LSTM is highly sensitive in nature. We will need to scale it. We will use Standard Scaler for this dataset, as MinMax scaler is inappropriate for stock prices.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
training_set_scaled = scaler.fit_transform(training_set)

# %%
training_set_scaled
# Out:
# array([[-0.50664719, -0.27598886, -1.17318122,  0.31578874, -0.66954713],
#        [-0.41585462, -0.10192933, -1.04595889,  0.37343179, -0.44310668],
#        [-0.48500502, -0.70438539, -1.13277686,  0.39017659, -0.61149418],
#        ...,
#        [-1.76718451,  1.39183159, -2.20478981,  0.9574418 ,  2.21724497],
#        [-1.61938282,  1.25673181, -1.98644742,  0.99941067,  2.11928586],
#        [-1.7587387 ,  1.3970298 , -2.21419904,  1.02463485,  1.95874425]])

# %% [markdown]
# **We will use set of 60 values as sequence to predict the final outcome.**  Our X_train will have 940 sequences each with length of 60. y_train will have 940 values of stock prices corresponding to each sequence

# %%
X_train = []
y_train = []
for i in range(60, 1000):
    X_train.append(training_set_scaled[i-60:i, 0])  # Selecting indicator/price sequence 
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
X_train.shape
# Out:
# (940, 60, 1)

# %%
y_train.shape
# Out:
# (940,)

# %%
#import models using Keras library
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
#Initialize the model
model = Sequential()

#Set the inputs for first layer
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))   # use of dropout to prevent any overfitting

# Add  three hidden layers
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units = 50))
model.add(Dropout(0.2))

# Get the output as single value
model.add(Dense(units = 1))

# set optimizer and loss metrics
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

#Fit the model 
model.fit(X_train, y_train, epochs = 50, batch_size = 32)
# Out:
# Epoch 1/50
# 30/30 [==============================] - 20s 53ms/step - loss: 0.4098
# Epoch 2/50
# 30/30 [==============================] - 2s 53ms/step - loss: 0.1488
# Epoch 3/50
# 30/30 [==============================] - 2s 55ms/step - loss: 0.1140
# Epoch 4/50
# 30/30 [==============================] - 2s 55ms/step - loss: 0.0906
# Epoch 5/50
# 30/30 [==============================] - 2s 55ms/step - loss: 0.0870
# Epoch 6/50
# 30/30 [==============================] - 2s 56ms/step - loss: 0.0752
# Epoch 7/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0679
# Epoch 8/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0623
# Epoch 9/50
# 30/30 [==============================] - 2s 56ms/step - loss: 0.0558
# Epoch 10/50
# 30/30 [==============================] - 2s 57ms/step - loss: 0.0621
# Epoch 11/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0559
# Epoch 12/50
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0557
# Epoch 13/50
# 30/30 [==============================] - 2s 53ms/step - loss: 0.0474
# Epoch 14/50
# 30/30 [==============================] - 2s 56ms/step - loss: 0.0574
# Epoch 15/50
# 30/30 [==============================] - 2s 53ms/step - loss: 0.0535
# Epoch 16/50
# 30/30 [==============================] - 2s 53ms/step - loss: 0.0472
# Epoch 17/50
# 30/30 [==============================] - 2s 61ms/step - loss: 0.0449
# Epoch 18/50
# 30/30 [==============================] - 2s 64ms/step - loss: 0.0453
# Epoch 19/50
# 30/30 [==============================] - 2s 65ms/step - loss: 0.0405
# Epoch 20/50
# 30/30 [==============================] - 2s 58ms/step - loss: 0.0443
# Epoch 21/50
# 30/30 [==============================] - 2s 58ms/step - loss: 0.0444
# Epoch 22/50
# 30/30 [==============================] - 2s 57ms/step - loss: 0.0371
# Epoch 23/50
# 30/30 [==============================] - 2s 59ms/step - loss: 0.0383
# Epoch 24/50
# 30/30 [==============================] - 2s 60ms/step - loss: 0.0410
# Epoch 25/50
# 30/30 [==============================] - 2s 58ms/step - loss: 0.0351: 0s - loss: 0.
# Epoch 26/50
# 30/30 [==============================] - 2s 59ms/step - loss: 0.0425
# Epoch 27/50
# 30/30 [==============================] - 2s 59ms/step - loss: 0.0404: 0s - loss: 0.04
# Epoch 28/50
# 30/30 [==============================] - 2s 62ms/step - loss: 0.0367
# Epoch 29/50
# 30/30 [==============================] - 2s 62ms/step - loss: 0.0344
# Epoch 30/50
# 30/30 [==============================] - 2s 58ms/step - loss: 0.0432: 0s - los
# Epoch 31/50
# 30/30 [==============================] - 2s 60ms/step - loss: 0.0378
# Epoch 32/50
# 30/30 [==============================] - 2s 57ms/step - loss: 0.0376
# Epoch 33/50
# 30/30 [==============================] - 2s 58ms/step - loss: 0.0394
# Epoch 34/50
# 30/30 [==============================] - 2s 61ms/step - loss: 0.0403: 0s
# Epoch 35/50
# 30/30 [==============================] - 2s 58ms/step - loss: 0.0314
# Epoch 36/50
# 30/30 [==============================] - 2s 60ms/step - loss: 0.0313
# Epoch 37/50
# 30/30 [==============================] - 2s 58ms/step - loss: 0.0317
# Epoch 38/50
# 30/30 [==============================] - 2s 58ms/step - loss: 0.0298
# Epoch 39/50
# 30/30 [==============================] - 2s 60ms/step - loss: 0.0288
# Epoch 40/50
# 30/30 [==============================] - 2s 60ms/step - loss: 0.0299
# Epoch 41/50
# 30/30 [==============================] - 2s 59ms/step - loss: 0.0337
# Epoch 42/50
# 30/30 [==============================] - 2s 58ms/step - loss: 0.0274
# Epoch 43/50
# 30/30 [==============================] - 2s 58ms/step - loss: 0.0281
# Epoch 44/50
# 30/30 [==============================] - 2s 58ms/step - loss: 0.0295
# Epoch 45/50
# 30/30 [==============================] - 2s 58ms/step - loss: 0.0257
# Epoch 46/50
# 30/30 [==============================] - 2s 58ms/step - loss: 0.0288
# Epoch 47/50
# 30/30 [==============================] - 2s 59ms/step - loss: 0.0259
# Epoch 48/50
# 30/30 [==============================] - 2s 65ms/step - loss: 0.0292
# Epoch 49/50
# 30/30 [==============================] - 2s 69ms/step - loss: 0.0251
# Epoch 50/50
# 30/30 [==============================] - 2s 66ms/step - loss: 0.0261

# %%
#Standard scalar for test set
scaler_test = StandardScaler()
test_set_scaled = scaler_test.fit_transform(df_final['Close'].values.reshape(-1,1))

# %%
#set the test set

dataset_total = pd.concat((df_final['Close'].iloc[:1000], df_final['Close'][1000:]), axis = 0)
inputs = dataset_total[len(dataset_total) - len(df_final['Close'][1000:]) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = scaler_test.transform(inputs)
X_test = []
for i in range(60, 291):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = model.predict(X_test)
predicted_stock_price = scaler_test.inverse_transform(predicted_stock_price)

# %%
predicted_stock_price
# Out:
# array([[62.319828],
#        [62.11951 ],
#        [59.50578 ],
#        [56.611935],
#        [54.458122],
#        [53.863907],
#        [53.53024 ],
#        [53.295345],
#        [52.93093 ],
#        [52.56837 ],
#        [52.30024 ],
#        [51.12874 ],
#        [50.180218],
#        [49.118134],
#        [48.44326 ],
#        [48.43372 ],
#        [48.530914],
#        [48.789967],
#        [49.07009 ],
#        [48.67478 ],
#        [47.80502 ],
#        [46.070705],
#        [44.593014],
#        [43.540657],
#        [43.552692],
#        [44.11541 ],
#        [44.860428],
#        [45.349094],
#        [45.76174 ],
#        [46.843422],
#        [48.08227 ],
#        [48.798046],
#        [49.14198 ],
#        [49.18423 ],
#        [48.7718  ],
#        [48.55951 ],
#        [48.046844],
#        [47.498558],
#        [46.931747],
#        [47.024925],
#        [48.060314],
#        [49.374336],
#        [49.952114],
#        [50.38897 ],
#        [50.50119 ],
#        [50.336   ],
#        [49.633247],
#        [48.936108],
#        [48.045856],
#        [47.14547 ],
#        [46.21226 ],
#        [44.994534],
#        [43.641182],
#        [42.76519 ],
#        [42.319202],
#        [41.807602],
#        [41.784428],
#        [42.369606],
#        [42.8981  ],
#        [43.23273 ],
#        [43.040913],
#        [42.508465],
#        [41.992725],
#        [41.025135],
#        [40.304386],
#        [38.862522],
#        [37.609875],
#        [36.798992],
#        [36.184475],
#        [36.343105],
#        [36.90141 ],
#        [37.390564],
#        [37.28329 ],
#        [36.86537 ],
#        [35.952583],
#        [35.12096 ],
#        [34.75997 ],
#        [34.693623],
#        [34.454983],
#        [34.12857 ],
#        [33.602962],
#        [33.116173],
#        [33.171608],
#        [33.356888],
#        [33.72897 ],
#        [34.354763],
#        [34.979145],
#        [35.66468 ],
#        [36.395622],
#        [36.829254],
#        [37.18472 ],
#        [37.344624],
#        [37.131046],
#        [36.826458],
#        [36.298912],
#        [36.191345],
#        [36.436478],
#        [36.162754],
#        [35.581783],
#        [34.5142  ],
#        [33.793034],
#        [33.444813],
#        [33.49808 ],
#        [33.651203],
#        [34.029198],
#        [34.34082 ],
#        [34.348732],
#        [35.515503],
#        [37.42488 ],
#        [39.296032],
#        [40.54485 ],
#        [41.777634],
#        [43.49281 ],
#        [45.324997],
#        [46.769478],
#        [47.883854],
#        [48.672283],
#        [50.32136 ],
#        [53.132584],
#        [55.806236],
#        [57.43517 ],
#        [57.001747],
#        [55.28111 ],
#        [53.7001  ],
#        [52.707417],
#        [53.381916],
#        [54.365578],
#        [55.190468],
#        [55.859447],
#        [56.70886 ],
#        [57.20743 ],
#        [56.907696],
#        [56.453663],
#        [55.953907],
#        [55.343285],
#        [54.63755 ],
#        [53.512394],
#        [51.975906],
#        [50.882053],
#        [50.139694],
#        [49.45646 ],
#        [48.791664],
#        [48.779903],
#        [48.925617],
#        [49.04487 ],
#        [50.21791 ],
#        [52.07008 ],
#        [54.7437  ],
#        [57.42367 ],
#        [59.700886],
#        [61.979023],
#        [63.46088 ],
#        [64.525185],
#        [64.493835],
#        [64.09003 ],
#        [63.63276 ],
#        [61.842773],
#        [59.466625],
#        [57.55791 ],
#        [55.882977],
#        [55.04106 ],
#        [54.413757],
#        [53.080368],
#        [51.692368],
#        [50.6468  ],
#        [51.35576 ],
#        [53.25773 ],
#        [55.044094],
#        [57.008595],
#        [58.45361 ],
#        [59.794144],
#        [60.776955],
#        [61.714382],
#        [63.026222],
#        [64.423615],
#        [64.76201 ],
#        [64.78407 ],
#        [65.699356],
#        [67.422485],
#        [70.15606 ],
#        [72.37727 ],
#        [71.96656 ],
#        [69.913994],
#        [67.63905 ],
#        [66.740616],
#        [68.08456 ],
#        [70.98702 ],
#        [73.81878 ],
#        [75.38655 ],
#        [76.06459 ],
#        [76.21945 ],
#        [75.98443 ],
#        [75.400505],
#        [73.67714 ],
#        [72.53177 ],
#        [70.9451  ],
#        [69.813805],
#        [68.80757 ],
#        [68.55999 ],
#        [69.69742 ],
#        [71.3858  ],
#        [73.28463 ],
#        [74.40719 ],
#        [74.58336 ],
#        [74.026184],
#        [74.121605],
#        [73.66844 ],
#        [73.01691 ],
#        [72.84276 ],
#        [72.712036],
#        [72.44747 ],
#        [71.684784],
#        [70.96487 ],
#        [71.67324 ],
#        [72.6458  ],
#        [72.619576],
#        [72.187904],
#        [70.99013 ],
#        [69.84001 ],
#        [68.99125 ],
#        [68.7736  ],
#        [69.191605],
#        [70.332436],
#        [72.42966 ],
#        [74.71406 ],
#        [75.75435 ],
#        [76.28046 ],
#        [76.274925],
#        [76.43839 ],
#        [76.79421 ],
#        [78.78092 ]], dtype=float32)

# %%
real_stock_price = df['Close'][1000:].values

# %%
real_stock_price
# Out:
# array([55.630001, 51.150002, 52.57    , 52.209999, 54.599998, 52.48    ,
#        52.93    , 52.299999, 52.419998, 52.459999, 48.950001, 50.73    ,
#        48.759998, 49.650002, 50.66    , 49.860001, 50.52    , 50.41    ,
#        48.110001, 47.439999, 44.34    , 45.400002, 44.950001, 47.279999,
#        47.459999, 47.82    , 47.16    , 47.700001, 50.419998, 50.189999,
#        48.849998, 49.040001, 48.560001, 47.27    , 48.5     , 46.580002,
#        46.849998, 46.369999, 48.459999, 50.75    , 50.889999, 48.810001,
#        50.459999, 49.419998, 49.09    , 47.419998, 47.970001, 46.540001,
#        46.349998, 45.610001, 44.099998, 43.389999, 44.330002, 44.380001,
#        43.259998, 44.950001, 46.209999, 45.34    , 45.209999, 43.700001,
#        43.130001, 43.139999, 40.830002, 41.860001, 38.      , 39.049999,
#        39.169998, 38.59    , 40.860001, 41.189999, 40.709999, 38.810001,
#        38.450001, 36.380001, 36.650002, 37.450001, 37.439999, 36.189999,
#        35.939999, 34.860001, 34.810001, 36.459999, 35.990002, 36.709999,
#        37.669998, 37.560001, 38.209999, 38.639999, 37.619999, 38.080002,
#        37.419998, 36.189999, 36.279999, 35.119999, 36.93    , 37.509998,
#        34.93    , 34.580002, 32.509998, 33.970001, 34.240002, 35.150002,
#        35.02    , 36.040001, 35.599998, 34.580002, 40.310001, 42.189999,
#        41.91    , 40.490002, 42.669998, 45.349998, 45.669998, 44.93    ,
#        45.459999, 45.389999, 50.380001, 54.419998, 53.      , 51.43    ,
#        46.880001, 46.529999, 47.82    , 48.169998, 53.      , 51.57    ,
#        52.150002, 52.959999, 54.68    , 53.599998, 52.080002, 53.16    ,
#        52.700001, 52.150002, 51.77    , 50.080002, 48.849998, 50.080002,
#        49.599998, 48.939999, 48.669998, 50.560001, 49.869999, 49.860001,
#        53.919998, 55.060001, 58.619999, 58.869999, 59.610001, 62.439999,
#        60.470001, 62.240002, 59.189999, 60.48    , 60.200001, 55.029999,
#        54.860001, 55.200001, 53.490002, 55.009998, 53.720001, 50.959999,
#        51.330002, 51.259998, 55.880001, 57.470001, 56.610001, 59.41    ,
#        58.220001, 60.209999, 59.639999, 61.02    , 63.099998, 63.540001,
#        60.57    , 62.509998, 66.099998, 67.849998, 72.370003, 70.589996,
#        64.559998, 64.980003, 64.470001, 66.989998, 71.43    , 74.580002,
#        74.589996, 73.610001, 75.110001, 75.309998, 75.      , 74.360001,
#        70.650002, 73.190002, 68.900002, 70.080002, 68.230003, 69.650002,
#        72.540001, 73.040001, 74.879997, 73.639999, 73.260002, 72.529999,
#        75.339996, 71.790001, 72.300003, 73.300003, 72.190002, 71.769997,
#        70.099998, 70.400002, 74.120003, 72.830002, 70.510002, 71.290001,
#        68.57    , 68.959999, 68.349998, 69.059998, 69.830002, 71.68    ,
#        74.980003, 75.93    , 73.639999, 75.970001, 75.010002, 76.709999,
#        76.980003, 83.099998])

# %%
plt.plot(real_stock_price, color = 'black', label = 'Actual Stock Price')
plt.plot(predicted_stock_price, color = 'green', label = 'Predicted Stock Price')
plt.title('EOG Resources Stock Price Prediction')
plt.xlabel('Time (Days)')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Stock price prediction very near the actual results also predicted stock follow the actual stock direction.
#
# ---
# ---
