# %%
#import all the basic libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the dataset in to dataframe
cvx = pd.read_csv('data/CVX.csv')

# %%
# Visually scan the data
cvx.head()
# Out:
#          Date        Open        High         Low       Close  Adj Close  \
# 0  2016-05-09  101.620003  101.800003   99.080002  100.349998  80.794678
# 1  2016-05-10  100.639999  101.290001  100.410004  101.269997  81.535400
# 2  2016-05-11  101.239998  101.739998  100.150002  101.139999  81.430748
# 3  2016-05-12  102.150002  102.419998  101.080002  102.120003  82.219772
# 4  2016-05-13  101.629997  102.040001  100.360001  100.739998  81.108696
#
#     Volume      OBV        TR     +DM 1  ...  12_day_EMA  30_day_EMA  MACD  \
# 0  9342100        0       NaN       NaN  ...         NaN         NaN   NaN
# 1  6698100  6698100       NaN       NaN  ...         NaN         NaN   NaN
# 2  6850700  -152600  1.589996  0.449997  ...         NaN         NaN   NaN
# 3  6532400  6379800  1.339996  0.680000  ...         NaN         NaN   NaN
# 4  5665200   714600  1.760002  0.000000  ...         NaN         NaN   NaN
#
#      Change      Gain     Loss   Avg Gain  Avg Loss  RS  RSI
# 0       NaN       NaN       NaN       NaN       NaN NaN  NaN
# 1  0.740722  0.740722  0.000000       NaN       NaN NaN  NaN
# 2 -0.104652  0.000000  0.104652       NaN       NaN NaN  NaN
# 3  0.789024  0.789024  0.000000       NaN       NaN NaN  NaN
# 4 -1.111076  0.000000  1.111076       NaN       NaN NaN  NaN
#
# [5 rows x 30 columns]

# %%
#Rows and columns in the dataframe
cvx.shape
# Out:
# (1259, 30)

# %% [markdown]
# ## EDA

# %%
#Check for null values in the columns
cvx.isna().sum()
# Out:
# Date           0
# Open           0
# High           0
# Low            0
# Close          0
# Adj Close      0
# Volume         0
# OBV            0
# TR             2
# +DM 1          2
# -DM 1          2
# TR14          15
# +DM14         15
# -DM14         15
# +DI14         15
# -DI14         15
# DI 14 Diff    15
# DI 14 Sum     15
# DX            15
# ADX           28
# 12_day_EMA    11
# 30_day_EMA    29
# MACD          29
# Change         1
# Gain           1
# Loss           1
# Avg Gain      14
# Avg Loss      14
# RS            14
# RSI           14
# dtype: int64

# %% [markdown]
# The null values in the dataframe exist as some columns required previous days information. We will drop all the rows with null values.

# %%
#Drop the null values rows
cvx = cvx.dropna()

# %%
cvx.head()
# Out:
#           Date        Open        High         Low       Close  Adj Close  \
# 29  2016-06-20  102.879997  103.400002  102.599998  102.610001  83.487595
# 30  2016-06-21  102.690002  103.449997  102.269997  103.239998  84.000191
# 31  2016-06-22  103.500000  103.550003  102.190002  102.290001  83.227249
# 32  2016-06-23  103.449997  104.449997  103.070000  104.440002  84.976555
# 33  2016-06-24  101.459999  103.010002  101.169998  101.900002  82.909904
#
#       Volume      OBV        TR     +DM 1  ...  12_day_EMA  30_day_EMA  \
# 29   6627000  -728100  1.830002  1.660004  ...  101.857500  101.272332
# 30   4938700  4210600  1.180000  0.000000  ...  102.072499  101.368666
# 31   4866400  -655800  1.360001  0.100006  ...  102.165833  101.402666
# 32   5593600  4937800  2.159996  0.899994  ...  102.259166  101.512666
# 33  11481400 -6543600  3.270004  0.000000  ...  102.160000  101.505333
#
#         MACD    Change      Gain     Loss   Avg Gain  Avg Loss        RS  \
# 29  0.585167  0.846177  0.846177  0.000000  0.291747  0.198178  1.472143
# 30  0.703833  0.512596  0.512596  0.000000  0.320805  0.198178  1.618767
# 31  0.763167 -0.772942  0.000000  0.772942  0.320805  0.218518  1.468090
# 32  0.746500  1.749306  1.749306  0.000000  0.438200  0.218518  2.005322
# 33  0.654667 -2.066651  0.000000  2.066651  0.408561  0.366136  1.115870
#
#           RSI
# 29  59.549267
# 30  61.814086
# 31  59.482833
# 32  66.725694
# 33  52.738121
#
# [5 rows x 30 columns]

# %%
cvx.isna().sum()
# Out:
# Date          0
# Open          0
# High          0
# Low           0
# Close         0
# Adj Close     0
# Volume        0
# OBV           0
# TR            0
# +DM 1         0
# -DM 1         0
# TR14          0
# +DM14         0
# -DM14         0
# +DI14         0
# -DI14         0
# DI 14 Diff    0
# DI 14 Sum     0
# DX            0
# ADX           0
# 12_day_EMA    0
# 30_day_EMA    0
# MACD          0
# Change        0
# Gain          0
# Loss          0
# Avg Gain      0
# Avg Loss      0
# RS            0
# RSI           0
# dtype: int64

# %% [markdown]
# Now our dataframe does not include any null values.

# %% [markdown]
# We will filter out the columns we need for modeling by creating a new dataframe.

# %%
# Final Dataframe
cvx_final = cvx[['Close', 'Volume','OBV','ADX','MACD','RSI']]

cvx_final.head()
# Out:
#          Close    Volume      OBV        ADX      MACD        RSI
# 29  102.610001   6627000  -728100  21.266787  0.585167  59.549267
# 30  103.239998   4938700  4210600  21.120981  0.703833  61.814086
# 31  102.290001   4866400  -655800  20.912818  0.763167  59.482833
# 32  104.440002   5593600  4937800  20.341569  0.746500  66.725694
# 33  101.900002  11481400 -6543600  21.149467  0.654667  52.738121

# %% [markdown]
# ---

# %% [markdown]
# ## Visualization

# %%
plt.figure(figsize = (10,7))
plt.plot( cvx["Close"])
plt.xlabel("Time (Days)")
plt.ylabel("Close Price")
plt.title("CVX Close Price")
plt.show()

# %%
plt.figure(figsize= (10,7))
plt.plot( cvx['OBV'], color = 'Orange')
plt.xlabel("Time (Days)")
plt.ylabel("Volume")
plt.title("CVX OBV")
plt.show()

# %%
plt.figure(figsize= (10,7))
plt.plot( cvx['MACD'], color = 'Purple')
plt.xlabel("Time (Days)")
plt.ylabel("MACD")
plt.title("CVX MACD")
plt.show()

# %%
plt.figure(figsize= (10,7))
plt.plot( cvx['RSI'], color = 'Green')
plt.xlabel("Time (Days)")
plt.ylabel("RSI")
plt.title("CVX RSI")
plt.show()

# %%
plt.figure(figsize= (10,7))
plt.plot( cvx['ADX'], color = 'Red')
plt.xlabel("Time (Days)")
plt.ylabel("ADX")
plt.title("CVX ADX")
plt.show()

# %% [markdown]
# We can see every indicator behave differently to price change. We can deduce that their is no correlation thee. Let's check its correlation by plotting each against one another.

# %%
sns.pairplot(cvx_final)

# %% [markdown]
# ### Correlation Matrix

# %%
# Compute the correlation matrix
corr = cvx_final.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap 
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,annot= True,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# From the above visuals it is clear that there is hardly any correlation between the technical indicators.

# %% [markdown]
# ---

# %% [markdown]
# ## **LSTM Modeling**

# %% [markdown]
# ### Set the Training set

# %%
#Selecting first 1000 values to train the dataset
training_set = cvx_final.iloc[:1000].values

# %%
training_set
# Out:
# array([[ 1.02610001e+02,  6.62700000e+06, -7.28100000e+05,
#          2.12667868e+01,  5.85166967e-01,  5.95492667e+01],
#        [ 1.03239998e+02,  4.93870000e+06,  4.21060000e+06,
#          2.11209810e+01,  7.03833133e-01,  6.18140862e+01],
#        [ 1.02290001e+02,  4.86640000e+06, -6.55800000e+05,
#          2.09128182e+01,  7.63166583e-01,  5.94828332e+01],
#        ...,
#        [ 1.00809998e+02,  1.27601000e+07,  2.19522500e+08,
#          2.46847484e+01,  1.68433275e+00,  7.01557643e+01],
#        [ 1.03239998e+02,  1.10907000e+07,  2.30613200e+08,
#          2.64306373e+01,  1.99666605e+00,  6.79061938e+01],
#        [ 1.01529999e+02,  1.07454000e+07,  2.19867800e+08,
#          2.62502284e+01,  2.39349922e+00,  7.07998949e+01]])

# %% [markdown]
# ### Feature Scaling

# %% [markdown]
# **Scaling the dataset:** LSTM is highly sensitive in nature. We will need to scale it. We will use Standard Scaler for this dataset, as MinMax scaler is inappropriate for stock prices.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
training_set_scaled = scaler.fit_transform(training_set)

# %%
training_set_scaled
# Out:
# array([[-0.93760205, -0.08970484, -1.64709989, -0.69225287,  0.19615258,
#          0.41218675],
#        [-0.8808843 , -0.54041852, -1.5911574 , -0.70161235,  0.23114524,
#          0.54460878],
#        [-0.96641121, -0.55971995, -1.64628092, -0.71497461,  0.24864168,
#          0.40830244],
#        ...,
#        [-1.09965384,  1.54760613,  0.84776023, -0.47284916,  0.52027808,
#          1.03233943],
#        [-0.8808843 ,  1.10193804,  0.97338869, -0.36077812,  0.61237991,
#          0.900809  ],
#        [-1.03483314,  1.00975571,  0.85167157, -0.37235882,  0.72939933,
#          1.07000119]])

# %% [markdown]
# **We will use set of 60 values as sequence to predict the final outcome.**  Our X_train will have 940 sequences each with length of 60. y_train will have 940 values of stock prices corresponding to each sequence

# %%
X_train = []
y_train = []
for i in range(60, 1000):
    X_train.append(training_set_scaled[i-60:i, 3])  # Selecting indicator sequence 
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
X_train.shape
# Out:
# (940, 60, 1)

# %%
y_train.shape
# Out:
# (940,)

# %%
#import models using Keras library
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
#Initialize the model
model = Sequential()

#Set the inputs for first layer
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))   # use of dropout to prevent any overfitting

# Add  three hidden layers
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units = 50))
model.add(Dropout(0.2))

# Get the output as single value
model.add(Dense(units = 1))

# set optimizer and loss metrics
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

#Fit the model 
model.fit(X_train, y_train, epochs = 50, batch_size = 32)
# Out:
# Epoch 1/50
# 30/30 [==============================] - 19s 56ms/step - loss: 0.9209
# Epoch 2/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.9098
# Epoch 3/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.8910
# Epoch 4/50
# 30/30 [==============================] - 2s 53ms/step - loss: 0.8501
# Epoch 5/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.7228
# Epoch 6/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.7525
# Epoch 7/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.5803
# Epoch 8/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.5243
# Epoch 9/50
# 30/30 [==============================] - 2s 52ms/step - loss: 0.4671
# Epoch 10/50
# 30/30 [==============================] - 2s 53ms/step - loss: 0.3697
# Epoch 11/50
# 30/30 [==============================] - 2s 51ms/step - loss: 0.3708
# Epoch 12/50
# 30/30 [==============================] - 2s 52ms/step - loss: 0.3628
# Epoch 13/50
# 30/30 [==============================] - 2s 52ms/step - loss: 0.3105
# Epoch 14/50
# 30/30 [==============================] - 2s 52ms/step - loss: 0.2728
# Epoch 15/50
# 30/30 [==============================] - 2s 53ms/step - loss: 0.2551
# Epoch 16/50
# 30/30 [==============================] - 2s 52ms/step - loss: 0.2147
# Epoch 17/50
# 30/30 [==============================] - 2s 52ms/step - loss: 0.2309
# Epoch 18/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.1681
# Epoch 19/50
# 30/30 [==============================] - 2s 52ms/step - loss: 0.1613
# Epoch 20/50
# 30/30 [==============================] - 2s 52ms/step - loss: 0.1601
# Epoch 21/50
# 30/30 [==============================] - 2s 53ms/step - loss: 0.1167
# Epoch 22/50
# 30/30 [==============================] - 2s 51ms/step - loss: 0.1432
# Epoch 23/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.1000
# Epoch 24/50
# 30/30 [==============================] - 2s 53ms/step - loss: 0.0917
# Epoch 25/50
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0752
# Epoch 26/50
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0844
# Epoch 27/50
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0703
# Epoch 28/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0575
# Epoch 29/50
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0689
# Epoch 30/50
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0624
# Epoch 31/50
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0509
# Epoch 32/50
# 30/30 [==============================] - 2s 53ms/step - loss: 0.0600
# Epoch 33/50
# 30/30 [==============================] - 2s 51ms/step - loss: 0.0573
# Epoch 34/50
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0484
# Epoch 35/50
# 30/30 [==============================] - 2s 51ms/step - loss: 0.0467
# Epoch 36/50
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0473
# Epoch 37/50
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0507
# Epoch 38/50
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0620
# Epoch 39/50
# 30/30 [==============================] - 2s 55ms/step - loss: 0.0535
# Epoch 40/50
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0528
# Epoch 41/50
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0406
# Epoch 42/50
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0464
# Epoch 43/50
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0351
# Epoch 44/50
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0421
# Epoch 45/50
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0370
# Epoch 46/50
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0395
# Epoch 47/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0392
# Epoch 48/50
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0393
# Epoch 49/50
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0427
# Epoch 50/50
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0378

# %%
#Standard scalar for test set
scaler_test = StandardScaler()
test_set_scaled = scaler_test.fit_transform(cvx_final['ADX'].values.reshape(-1,1))

# %%
#set the 

dataset_total = pd.concat((cvx_final['ADX'].iloc[:1000], cvx_final['ADX'][1000:]), axis = 0)
inputs = dataset_total[len(dataset_total) - len(cvx_final['ADX'][1000:]) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = scaler_test.transform(inputs)
X_test = []
for i in range(60, 291):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = model.predict(X_test)
predicted_stock_price = scaler_test.inverse_transform(predicted_stock_price)

# %%
predicted_stock_price
# Out:
# array([[16.40592 ],
#        [17.523737],
#        [18.637497],
#        [20.030453],
#        [21.63163 ],
#        [23.189142],
#        [24.410738],
#        [25.088541],
#        [25.242819],
#        [25.060192],
#        [24.76825 ],
#        [24.527193],
#        [24.357967],
#        [24.087696],
#        [23.580305],
#        [22.947613],
#        [22.370161],
#        [21.856066],
#        [21.445425],
#        [21.096272],
#        [20.915472],
#        [20.996592],
#        [21.35418 ],
#        [21.939396],
#        [22.692606],
#        [23.616983],
#        [24.529266],
#        [25.334751],
#        [26.097946],
#        [26.9007  ],
#        [27.404425],
#        [27.678381],
#        [28.282305],
#        [28.905407],
#        [28.593079],
#        [27.734291],
#        [26.616693],
#        [25.458117],
#        [24.361607],
#        [23.148922],
#        [21.84813 ],
#        [20.804018],
#        [20.029799],
#        [19.475206],
#        [19.114897],
#        [18.928236],
#        [18.918566],
#        [19.081686],
#        [19.382273],
#        [19.7684  ],
#        [20.202494],
#        [20.66398 ],
#        [21.155457],
#        [21.65944 ],
#        [22.161346],
#        [22.670063],
#        [23.19085 ],
#        [23.740217],
#        [24.359934],
#        [25.10259 ],
#        [25.95572 ],
#        [26.880903],
#        [27.842438],
#        [28.829523],
#        [29.870775],
#        [30.931204],
#        [32.002068],
#        [33.06304 ],
#        [34.070896],
#        [34.97921 ],
#        [35.776203],
#        [36.28294 ],
#        [36.445183],
#        [36.44788 ],
#        [36.464268],
#        [36.57443 ],
#        [36.764168],
#        [37.005047],
#        [37.308132],
#        [37.68106 ],
#        [38.160404],
#        [38.770435],
#        [39.525826],
#        [40.46497 ],
#        [41.66703 ],
#        [43.16724 ],
#        [44.921715],
#        [46.738434],
#        [48.40402 ],
#        [49.75352 ],
#        [50.718975],
#        [51.30308 ],
#        [51.533745],
#        [51.407578],
#        [50.872597],
#        [49.807796],
#        [48.014885],
#        [45.30874 ],
#        [41.64451 ],
#        [37.25414 ],
#        [32.553192],
#        [27.966331],
#        [23.794699],
#        [20.151878],
#        [17.163862],
#        [15.024981],
#        [13.766663],
#        [13.28796 ],
#        [13.461643],
#        [14.252399],
#        [15.489534],
#        [17.11265 ],
#        [19.305674],
#        [23.08908 ],
#        [29.962067],
#        [35.051235],
#        [39.02064 ],
#        [43.044224],
#        [40.184742],
#        [33.193466],
#        [40.084034],
#        [46.157116],
#        [49.06575 ],
#        [50.678413],
#        [51.874573],
#        [52.897083],
#        [53.840633],
#        [54.767067],
#        [55.709484],
#        [56.63118 ],
#        [57.438675],
#        [56.243374],
#        [54.29954 ],
#        [53.619015],
#        [53.197475],
#        [52.844162],
#        [52.489197],
#        [52.054703],
#        [51.450325],
#        [50.7578  ],
#        [50.016365],
#        [49.169754],
#        [48.137913],
#        [47.393906],
#        [46.8214  ],
#        [45.732254],
#        [44.00875 ],
#        [41.893673],
#        [40.164715],
#        [39.318085],
#        [38.85558 ],
#        [38.445747],
#        [37.944397],
#        [37.2321  ],
#        [36.172497],
#        [34.730614],
#        [32.851112],
#        [30.923195],
#        [29.752672],
#        [29.611305],
#        [30.083061],
#        [30.846577],
#        [31.777187],
#        [32.81058 ],
#        [33.836884],
#        [34.826393],
#        [35.687016],
#        [36.016632],
#        [35.795074],
#        [34.17569 ],
#        [29.401892],
#        [24.576796],
#        [22.5914  ],
#        [21.573196],
#        [20.90146 ],
#        [20.856703],
#        [21.495436],
#        [22.677982],
#        [24.386595],
#        [27.050413],
#        [31.48787 ],
#        [36.68279 ],
#        [41.43402 ],
#        [45.173927],
#        [47.728874],
#        [49.41858 ],
#        [50.64706 ],
#        [51.59772 ],
#        [52.354027],
#        [52.987324],
#        [53.559303],
#        [54.119404],
#        [54.64491 ],
#        [55.107204],
#        [55.449123],
#        [55.57686 ],
#        [55.43913 ],
#        [55.00017 ],
#        [54.280582],
#        [53.33354 ],
#        [52.24879 ],
#        [51.077194],
#        [49.895947],
#        [48.75843 ],
#        [47.713303],
#        [46.80696 ],
#        [46.052666],
#        [45.347366],
#        [44.50545 ],
#        [43.346367],
#        [41.70245 ],
#        [39.45026 ],
#        [36.385662],
#        [32.594616],
#        [28.178406],
#        [23.768663],
#        [19.817142],
#        [16.714815],
#        [14.460207],
#        [13.031624],
#        [12.414005],
#        [12.473948],
#        [13.10343 ],
#        [13.799454],
#        [14.139675],
#        [13.846048],
#        [13.401089],
#        [12.807495],
#        [12.38143 ],
#        [13.461504],
#        [14.246958]], dtype=float32)

# %%
real_stock_price = cvx['Close'][1000:].values

# %%
real_stock_price
# Out:
# array([ 97.580002,  89.370003,  92.389999,  91.230003,  94.029999,
#         91.540001,  91.940002,  90.629997,  91.589996,  91.440002,
#         87.639999,  89.209999,  86.459999,  87.669998,  89.230003,
#         87.620003,  88.309998,  88.57    ,  86.309998,  86.349998,
#         82.739998,  85.230003,  85.400002,  88.349998,  88.889999,
#         88.360001,  87.190002,  85.269997,  91.389999,  91.040001,
#         91.010002,  90.129997,  91.040001,  89.110001,  90.07    ,
#         86.269997,  83.940002,  84.809998,  86.489998,  87.199997,
#         87.470001,  86.800003,  89.730003,  89.620003,  90.720001,
#         89.82    ,  90.349998,  90.769997,  87.629997,  86.389999,
#         84.809998,  85.080002,  87.199997,  86.129997,  84.779999,
#         84.910004,  85.629997,  83.93    ,  83.080002,  83.190002,
#         82.279999,  81.93    ,  78.970001,  80.029999,  78.150002,
#         77.690002,  77.290001,  76.349998,  78.559998,  78.790001,
#         78.209999,  76.300003,  75.529999,  71.949997,  71.800003,
#         71.830002,  73.93    ,  71.900002,  72.      ,  70.419998,
#         71.190002,  72.699997,  72.300003,  73.779999,  75.220001,
#         74.      ,  74.510002,  73.400002,  72.949997,  73.510002,
#         72.889999,  71.279999,  71.68    ,  70.870003,  73.400002,
#         72.57    ,  70.940002,  69.510002,  66.879997,  68.800003,
#         69.5     ,  72.150002,  71.739998,  71.769997,  72.139999,
#         71.150002,  79.400002,  83.07    ,  82.459999,  80.669998,
#         83.029999,  88.959999,  87.040001,  84.279999,  85.730003,
#         85.790001,  91.029999,  95.620003,  92.139999,  91.309998,
#         87.18    ,  87.449997,  89.870003,  89.800003,  93.279999,
#         90.760002,  91.540001,  90.440002,  93.349998,  92.449997,
#         89.440002,  89.370003,  88.690002,  88.410004,  87.190002,
#         86.089996,  84.360001,  85.690002,  85.330002,  84.900002,
#         84.610001,  85.330002,  84.449997,  84.709999,  87.      ,
#         89.800003,  90.220001,  91.080002,  91.599998,  93.339996,
#         93.25    ,  95.489998,  92.089996,  94.510002,  95.379997,
#         92.010002,  91.730003,  90.900002,  89.360001,  88.199997,
#         89.019997,  85.199997,  86.410004,  87.059998,  88.959999,
#         89.      ,  89.260002,  91.480003,  90.959999,  92.519997,
#         92.019997,  92.550003,  93.129997,  95.919998,  95.      ,
#         95.800003,  98.389999,  99.629997, 103.309998, 102.349998,
#        100.      , 102.050003, 102.440002, 103.589996, 104.5     ,
#        109.      , 109.75    , 109.5     , 111.370003, 111.190002,
#        111.559998, 110.25    , 107.639999, 108.029999, 104.120003,
#        103.379997, 102.540001, 101.970001, 104.699997, 105.07    ,
#        107.480003, 106.919998, 105.93    , 104.790001, 105.75    ,
#        104.510002, 103.580002, 104.190002, 103.019997, 102.919998,
#        101.779999, 102.239998, 104.269997, 103.419998, 102.959999,
#        103.260002, 101.330002, 102.730003, 100.949997, 101.550003,
#        101.519997, 102.699997, 105.220001, 106.900002, 103.07    ,
#        105.529999, 106.110001, 108.959999, 109.019997, 110.019997])

# %%
plt.plot(real_stock_price, color = 'black', label = 'Actual Stock Price')
plt.plot(predicted_stock_price, color = 'green', label = 'Predicted Stock Price')
plt.title('CHEVRON Stock Price Prediction')
plt.xlabel('Time (Days)')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Stock price prediction with ADX is nowhere near the actual results but there is relation between direction of stock and ADX direction.
#
# ---
# ---
