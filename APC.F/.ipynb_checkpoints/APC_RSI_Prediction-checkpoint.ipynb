# %%
#import all the basic libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the dataset in to dataframe
df = pd.read_csv('data/APC.F.csv')

# %%
# Visually scan the data
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume  \
# 0  2016-05-09  20.387501  20.551500  20.350000  20.395500  18.873899   38404
# 1  2016-05-10  20.450001  20.549999  20.212250  20.481501  18.953482   35316
# 2  2016-05-11  20.447500  20.475500  20.306499  20.333000  18.816065   26424
# 3  2016-05-12  20.275000  20.375000  19.622000  19.815500  18.337172   43336
# 4  2016-05-13  19.825001  20.306499  19.750000  20.110750  18.610397   96508
#
#      OBV  12_day_EMA  30_day_EMA  MACD    Change      Gain     Loss   \
# 0      0         NaN         NaN   NaN       NaN       NaN       NaN
# 1  35316         NaN         NaN   NaN  0.086001  0.086001  0.000000
# 2   8892         NaN         NaN   NaN -0.148501  0.000000  0.148501
# 3 -34444         NaN         NaN   NaN -0.517500  0.789024  0.517500
# 4  62064         NaN         NaN   NaN  0.295250  0.000000  0.000000
#
#    Avg Gain  Avg Loss  RS  RSI
# 0       NaN       NaN NaN  NaN
# 1       NaN       NaN NaN  NaN
# 2       NaN       NaN NaN  NaN
# 3       NaN       NaN NaN  NaN
# 4       NaN       NaN NaN  NaN

# %%
#Rows and columns in the dataframe
df.shape
# Out:
# (1267, 18)

# %% [markdown]
# ## EDA

# %%
#Check for null values in the columns
df.isna().sum()
# Out:
# Date           0
# Open           0
# High           0
# Low            0
# Close          0
# Adj Close      0
# Volume         0
# OBV            0
# 12_day_EMA    11
# 30_day_EMA    29
# MACD          29
# Change         1
# Gain           1
# Loss           1
# Avg Gain      14
# Avg Loss      14
# RS            14
# RSI           14
# dtype: int64

# %% [markdown]
# The null values in the dataframe exist as some columns required previous days information. We will drop all the rows with null values.

# %%
#Drop the null values rows
df = df.dropna()

# %%
df.head()
# Out:
#           Date       Open       High        Low      Close  Adj Close  Volume  \
# 29  2016-06-20  21.152750  21.299999  21.123751  21.224001  19.640594   31344
# 30  2016-06-21  21.002501  21.387251  20.787750  21.249250  19.663960   30424
# 31  2016-06-22  21.424999  21.447001  21.110750  21.162500  19.583679   35228
# 32  2016-06-23  21.200001  21.225000  20.897751  21.062500  19.491137   32368
# 33  2016-06-24  20.007500  21.339500  20.007500  20.989250  19.423353  181888
#
#        OBV  12_day_EMA  30_day_EMA      MACD    Change      Gain    Loss   \
# 29  373468   21.672500   21.489900  0.182600 -0.017750  0.846177  0.01775
# 30  403892   21.638938   21.518358  0.120579  0.025249  0.512596  0.00000
# 31  368664   21.587438   21.541058  0.046379 -0.086750  0.000000  0.08675
# 32  336296   21.518292   21.565375 -0.047083 -0.100000  1.749306  0.10000
# 33  154408   21.461417   21.604500 -0.143083 -0.073250  0.000000  0.07325
#
#     Avg Gain  Avg Loss        RS        RSI
# 29  0.291747  0.138500  2.106477  67.809189
# 30  0.320805  0.120161  2.669796  72.750532
# 31  0.320805  0.103518  3.099027  75.603967
# 32  0.438200  0.099696  4.395341  81.465490
# 33  0.408561  0.104929  3.893703  79.565574

# %%
df.isna().sum()
# Out:
# Date          0
# Open          0
# High          0
# Low           0
# Close         0
# Adj Close     0
# Volume        0
# OBV           0
# 12_day_EMA    0
# 30_day_EMA    0
# MACD          0
# Change        0
# Gain          0
# Loss          0
# Avg Gain      0
# Avg Loss      0
# RS            0
# RSI           0
# dtype: int64

# %% [markdown]
# Now our dataframe does not include any null values.

# %% [markdown]
# We will filter out the columns we need for modeling by creating a new dataframe.

# %%
# Final Dataframe
df_final = df[['Close', 'Volume','OBV','MACD','RSI']]

df_final.head()
# Out:
#         Close  Volume     OBV      MACD        RSI
# 29  21.224001   31344  373468  0.182600  67.809189
# 30  21.249250   30424  403892  0.120579  72.750532
# 31  21.162500   35228  368664  0.046379  75.603967
# 32  21.062500   32368  336296 -0.047083  81.465490
# 33  20.989250  181888  154408 -0.143083  79.565574

# %% [markdown]
# ---

# %% [markdown]
# ## Visualization

# %%
plt.figure(figsize = (10,7))
plt.plot( df["Close"])
plt.xlabel("Time (Days)")
plt.ylabel("Close Price")
plt.title("APC.F Close Price")
plt.show()

# %%
plt.figure(figsize= (10,7))
plt.plot( df['OBV'], color = 'Orange')
plt.xlabel("Time (Days)")
plt.ylabel("Volume")
plt.title("APC.F OBV")
plt.show()

# %%
plt.figure(figsize= (10,7))
plt.plot( df['MACD'], color = 'Purple')
plt.xlabel("Time (Days)")
plt.ylabel("MACD")
plt.title("APC.F MACD")
plt.show()

# %%
plt.figure(figsize= (10,7))
plt.plot( df['RSI'], color = 'Green')
plt.xlabel("Time (Days)")
plt.ylabel("RSI")
plt.title("APC.F RSI")
plt.show()

# %% [markdown]
# We can see every indicator behave differently to price change. We can deduce that their is no correlation thee. Let's check its correlation by plotting each against one another.

# %%
sns.pairplot(df_final)

# %% [markdown]
# ### Correlation Matrix

# %%
# Compute the correlation matrix
corr = df_final.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap 
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,annot= True,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# From the above visuals it is clear that there is hardly any correlation between the technical indicators.

# %% [markdown]
# ---

# %% [markdown]
# ## **LSTM Modeling**

# %% [markdown]
# ### Set the Training set

# %%
#Selecting first 1000 values to train the dataset
training_set = df_final.iloc[:1000].values

# %%
training_set
# Out:
# array([[2.12240010e+01, 3.13440000e+04, 3.73468000e+05, 1.82599900e-01,
#         6.78091887e+01],
#        [2.12492500e+01, 3.04240000e+04, 4.03892000e+05, 1.20579067e-01,
#         7.27505319e+01],
#        [2.11625000e+01, 3.52280000e+04, 3.68664000e+05, 4.63791000e-02,
#         7.56039670e+01],
#        ...,
#        [7.19000020e+01, 1.42800000e+04, 2.34500400e+06, 3.43354148e+00,
#         7.84887221e+01],
#        [7.28375020e+01, 1.14600000e+04, 2.35646400e+06, 3.15145842e+00,
#         7.66582839e+01],
#        [7.18625030e+01, 1.84880000e+04, 2.33797600e+06, 3.05583363e+00,
#         7.38169515e+01]])

# %% [markdown]
# ### Feature Scaling

# %% [markdown]
# **Scaling the dataset:** LSTM is highly sensitive in nature. We will need to scale it. We will use Standard Scaler for this dataset, as MinMax scaler is inappropriate for stock prices.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
training_set_scaled = scaler.fit_transform(training_set)

# %%
training_set_scaled
# Out:
# array([[-1.54513265, -0.12082849, -2.37208179, -0.15260389, -0.31151298],
#        [-1.54311911, -0.15013795, -2.32752597, -0.18978117,  0.07179064],
#        [-1.55003718,  0.00290839, -2.37911723, -0.23425903,  0.2931337 ],
#        ...,
#        [ 2.49613802, -0.66445522,  0.51522459,  1.79611528,  0.51690626],
#        [ 2.57090104, -0.75429508,  0.53200772,  1.62702559,  0.37491783],
#        [ 2.49314757, -0.53039631,  0.50493212,  1.56970502,  0.15451359]])

# %% [markdown]
# **We will use set of 60 values as sequence to predict the final outcome.**  Our X_train will have 940 sequences each with length of 60. y_train will have 940 values of stock prices corresponding to each sequence

# %%
X_train = []
y_train = []
for i in range(60, 1000):
    X_train.append(training_set_scaled[i-60:i, 0])  # Selecting indicator/price sequence 
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
X_train.shape
# Out:
# (940, 60, 1)

# %%
y_train.shape
# Out:
# (940,)

# %%
#import models using Keras library
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
#Initialize the model
model = Sequential()

#Set the inputs for first layer
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))   # use of dropout to prevent any overfitting

# Add  three hidden layers
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units = 50))
model.add(Dropout(0.2))

# Get the output as single value
model.add(Dense(units = 1))

# set optimizer and loss metrics
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

#Fit the model 
model.fit(X_train, y_train, epochs = 50, batch_size = 32)
# Out:
# Epoch 1/50
# 30/30 [==============================] - 20s 57ms/step - loss: 0.4195
# Epoch 2/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0856
# Epoch 3/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0497
# Epoch 4/50
# 30/30 [==============================] - 2s 56ms/step - loss: 0.0414
# Epoch 5/50
# 30/30 [==============================] - 2s 55ms/step - loss: 0.0440
# Epoch 6/50
# 30/30 [==============================] - 2s 62ms/step - loss: 0.0307
# Epoch 7/50
# 30/30 [==============================] - 2s 56ms/step - loss: 0.0305
# Epoch 8/50
# 30/30 [==============================] - 2s 55ms/step - loss: 0.0312
# Epoch 9/50
# 30/30 [==============================] - 2s 55ms/step - loss: 0.0307
# Epoch 10/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0287
# Epoch 11/50
# 30/30 [==============================] - 2s 59ms/step - loss: 0.0274
# Epoch 12/50
# 30/30 [==============================] - 2s 56ms/step - loss: 0.0243
# Epoch 13/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0305
# Epoch 14/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0277
# Epoch 15/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0317
# Epoch 16/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0221
# Epoch 17/50
# 30/30 [==============================] - 2s 55ms/step - loss: 0.0250
# Epoch 18/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0265
# Epoch 19/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0225
# Epoch 20/50
# 30/30 [==============================] - 2s 56ms/step - loss: 0.0200
# Epoch 21/50
# 30/30 [==============================] - 2s 58ms/step - loss: 0.0223
# Epoch 22/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0229
# Epoch 23/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0258
# Epoch 24/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0249
# Epoch 25/50
# 30/30 [==============================] - 2s 56ms/step - loss: 0.0202
# Epoch 26/50
# 30/30 [==============================] - 2s 56ms/step - loss: 0.0226
# Epoch 27/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0229
# Epoch 28/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0200
# Epoch 29/50
# 30/30 [==============================] - 2s 57ms/step - loss: 0.0240
# Epoch 30/50
# 30/30 [==============================] - 2s 55ms/step - loss: 0.0252
# Epoch 31/50
# 30/30 [==============================] - 2s 57ms/step - loss: 0.0225
# Epoch 32/50
# 30/30 [==============================] - 2s 58ms/step - loss: 0.0193
# Epoch 33/50
# 30/30 [==============================] - 2s 55ms/step - loss: 0.0222
# Epoch 34/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0214
# Epoch 35/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0191
# Epoch 36/50
# 30/30 [==============================] - 2s 56ms/step - loss: 0.0195
# Epoch 37/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0201
# Epoch 38/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0192
# Epoch 39/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0207
# Epoch 40/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0177
# Epoch 41/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0188
# Epoch 42/50
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0170
# Epoch 43/50
# 30/30 [==============================] - 2s 65ms/step - loss: 0.0161
# Epoch 44/50
# 30/30 [==============================] - 2s 58ms/step - loss: 0.0157
# Epoch 45/50
# 30/30 [==============================] - 2s 58ms/step - loss: 0.0199
# Epoch 46/50
# 30/30 [==============================] - 2s 59ms/step - loss: 0.0178
# Epoch 47/50
# 30/30 [==============================] - 2s 58ms/step - loss: 0.0206
# Epoch 48/50
# 30/30 [==============================] - 2s 59ms/step - loss: 0.0215
# Epoch 49/50
# 30/30 [==============================] - 2s 59ms/step - loss: 0.0203
# Epoch 50/50
# 30/30 [==============================] - 2s 60ms/step - loss: 0.0180

# %%
#Standard scalar for test set
scaler_test = StandardScaler()
test_set_scaled = scaler_test.fit_transform(df_final['Close'].values.reshape(-1,1))

# %%
#set the test set

dataset_total = pd.concat((df_final['Close'].iloc[:1000], df_final['Close'][1000:]), axis = 0)
inputs = dataset_total[len(dataset_total) - len(df_final['Close'][1000:]) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = scaler_test.transform(inputs)
X_test = []
for i in range(60, 291):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = model.predict(X_test)
predicted_stock_price = scaler_test.inverse_transform(predicted_stock_price)

# %%
predicted_stock_price
# Out:
# array([[ 75.030304],
#        [ 74.849045],
#        [ 74.60539 ],
#        [ 74.31077 ],
#        [ 74.117615],
#        [ 74.10958 ],
#        [ 74.45702 ],
#        [ 75.239105],
#        [ 76.23039 ],
#        [ 77.13533 ],
#        [ 77.8097  ],
#        [ 78.40521 ],
#        [ 79.073975],
#        [ 79.79572 ],
#        [ 80.44855 ],
#        [ 81.035645],
#        [ 81.7365  ],
#        [ 82.453735],
#        [ 83.11881 ],
#        [ 83.62733 ],
#        [ 83.95362 ],
#        [ 84.14291 ],
#        [ 84.28666 ],
#        [ 84.43944 ],
#        [ 84.57386 ],
#        [ 84.76674 ],
#        [ 85.082146],
#        [ 85.5092  ],
#        [ 86.06324 ],
#        [ 86.65325 ],
#        [ 87.34706 ],
#        [ 87.96014 ],
#        [ 88.45582 ],
#        [ 88.74641 ],
#        [ 88.828575],
#        [ 88.82056 ],
#        [ 88.77765 ],
#        [ 88.66227 ],
#        [ 88.259865],
#        [ 87.43742 ],
#        [ 86.386635],
#        [ 85.30903 ],
#        [ 84.354004],
#        [ 83.63556 ],
#        [ 83.60309 ],
#        [ 84.66409 ],
#        [ 86.70324 ],
#        [ 89.16242 ],
#        [ 91.682076],
#        [ 93.937874],
#        [ 95.837425],
#        [ 97.32039 ],
#        [ 98.46526 ],
#        [ 99.45315 ],
#        [100.31407 ],
#        [101.04266 ],
#        [101.67621 ],
#        [102.296616],
#        [102.96121 ],
#        [103.909966],
#        [105.2441  ],
#        [106.678406],
#        [108.08161 ],
#        [109.28729 ],
#        [110.24503 ],
#        [111.139015],
#        [112.12582 ],
#        [113.073814],
#        [113.669556],
#        [113.78836 ],
#        [113.62116 ],
#        [113.18481 ],
#        [112.613144],
#        [111.90994 ],
#        [110.954056],
#        [109.87688 ],
#        [108.8862  ],
#        [107.87225 ],
#        [106.665016],
#        [105.06489 ],
#        [103.10717 ],
#        [101.057686],
#        [ 99.021545],
#        [ 97.119736],
#        [ 95.501144],
#        [ 94.36785 ],
#        [ 93.70222 ],
#        [ 93.51556 ],
#        [ 93.72854 ],
#        [ 94.09762 ],
#        [ 94.55311 ],
#        [ 95.02426 ],
#        [ 95.55818 ],
#        [ 96.154305],
#        [ 96.86725 ],
#        [ 98.06936 ],
#        [ 99.59783 ],
#        [101.22758 ],
#        [102.77385 ],
#        [104.14372 ],
#        [105.21321 ],
#        [105.993385],
#        [106.47464 ],
#        [106.70463 ],
#        [106.69296 ],
#        [106.52714 ],
#        [106.405334],
#        [106.28304 ],
#        [106.274025],
#        [106.14169 ],
#        [105.78779 ],
#        [105.34813 ],
#        [105.0807  ],
#        [105.171875],
#        [105.58936 ],
#        [106.23029 ],
#        [106.8352  ],
#        [107.39911 ],
#        [107.86299 ],
#        [108.180626],
#        [108.41022 ],
#        [108.609695],
#        [108.69761 ],
#        [108.64627 ],
#        [108.45276 ],
#        [107.966545],
#        [107.27603 ],
#        [106.58423 ],
#        [106.04052 ],
#        [105.613716],
#        [105.37012 ],
#        [105.480515],
#        [105.80356 ],
#        [106.23386 ],
#        [106.634514],
#        [106.99333 ],
#        [107.38321 ],
#        [107.76967 ],
#        [108.11881 ],
#        [108.36614 ],
#        [108.52656 ],
#        [108.76593 ],
#        [109.16813 ],
#        [109.64547 ],
#        [110.08602 ],
#        [110.43874 ],
#        [110.933876],
#        [111.50289 ],
#        [112.20814 ],
#        [112.961586],
#        [113.63148 ],
#        [114.04782 ],
#        [114.24677 ],
#        [114.2619  ],
#        [114.192474],
#        [114.08161 ],
#        [114.011086],
#        [113.90942 ],
#        [113.843735],
#        [113.79309 ],
#        [113.77145 ],
#        [113.71978 ],
#        [113.64106 ],
#        [113.63954 ],
#        [113.81463 ],
#        [114.15446 ],
#        [114.66281 ],
#        [115.28513 ],
#        [115.88182 ],
#        [116.40815 ],
#        [116.626564],
#        [116.653755],
#        [116.56842 ],
#        [116.43456 ],
#        [116.35318 ],
#        [116.30847 ],
#        [116.29331 ],
#        [116.22965 ],
#        [116.11476 ],
#        [115.92462 ],
#        [115.66064 ],
#        [115.41075 ],
#        [115.13813 ],
#        [114.8134  ],
#        [114.37657 ],
#        [113.910385],
#        [113.32493 ],
#        [112.570526],
#        [111.69357 ],
#        [110.65343 ],
#        [109.495186],
#        [108.444664],
#        [107.61042 ],
#        [106.89076 ],
#        [106.142624],
#        [105.36699 ],
#        [104.574585],
#        [104.02945 ],
#        [103.65579 ],
#        [103.49945 ],
#        [103.45945 ],
#        [103.544525],
#        [103.86818 ],
#        [104.3439  ],
#        [104.76593 ],
#        [105.000656],
#        [105.08118 ],
#        [105.1596  ],
#        [105.178635],
#        [105.16928 ],
#        [105.12552 ],
#        [105.23151 ],
#        [105.37624 ],
#        [105.67334 ],
#        [106.04487 ],
#        [106.54147 ],
#        [107.17551 ],
#        [107.94687 ],
#        [108.83073 ],
#        [109.764854],
#        [110.71673 ],
#        [111.59416 ],
#        [112.40451 ],
#        [113.07595 ],
#        [113.62526 ],
#        [114.047874],
#        [114.347466],
#        [114.55481 ],
#        [114.75703 ],
#        [114.994675],
#        [115.29451 ]], dtype=float32)

# %%
real_stock_price = df['Close'][1000:].values

# %%
real_stock_price
# Out:
# array([ 72.0625  ,  71.962502,  71.349998,  73.212502,  73.337502,
#         76.      ,  77.324997,  75.724998,  74.900002,  75.262497,
#         78.      ,  79.      ,  78.5     ,  77.875   ,  79.1875  ,
#         82.      ,  80.125   ,  80.762497,  80.037498,  80.262497,
#         80.699997,  81.387497,  81.5625  ,  81.012497,  82.625   ,
#         83.412498,  83.587502,  84.787498,  84.337502,  86.775002,
#         84.324997,  85.449997,  84.212502,  84.162498,  85.349998,
#         84.925003,  83.875   ,  80.4375  ,  78.574997,  80.4375  ,
#         80.287498,  80.150002,  80.75    ,  87.337502,  92.5625  ,
#         93.287498,  92.212502,  95.025002,  94.337502,  95.724998,
#         94.862503,  95.887497,  97.724998,  96.849998,  96.512497,
#         97.      ,  98.25    ,  99.037498, 104.      , 107.349998,
#        104.837502, 106.762497, 105.5     , 105.199997, 109.620003,
#        113.220001, 111.080002, 103.800003,  99.639999, 102.099998,
#         98.589996,  99.5     ,  97.440002,  93.5     ,  95.900002,
#         98.690002,  95.739998,  93.040001,  90.32    ,  91.160004,
#         94.43    ,  93.080002,  93.940002,  95.629997,  98.18    ,
#         97.440002,  99.599998,  99.57    ,  97.230003,  97.989998,
#         97.650002,  97.989998,  97.690002,  98.32    , 105.400002,
#        102.459999, 102.540001, 102.900002, 102.639999, 100.199997,
#        100.400002,  98.580002,  98.      ,  96.900002,  96.650002,
#         98.410004,  95.989998,  99.279999,  93.059998,  92.5     ,
#         94.      ,  97.82    , 100.300003, 100.080002, 101.260002,
#         98.900002, 101.400002, 100.580002, 100.599998, 101.360001,
#        101.419998, 100.459999,  99.529999,  99.769997,  96.870003,
#         97.330002,  97.470001,  97.82    ,  97.68    , 100.279999,
#        102.199997, 101.720001, 101.199997, 100.260002, 102.300003,
#        103.080002, 101.139999, 101.519997, 100.199997, 100.900002,
#        104.239998, 104.879997, 104.620003, 103.720001, 103.660004,
#        109.199997, 108.480003, 111.660004, 111.120003, 110.360001,
#        105.540001, 106.120003, 104.919998, 106.260002, 107.5     ,
#        106.400002, 105.32    , 107.5     , 106.519997, 106.639999,
#        106.      , 105.480003, 109.      , 112.059998, 113.68    ,
#        117.440002, 117.699997, 118.400002, 115.459999, 108.599998,
#        111.660004, 112.379997, 112.080002, 113.879997, 113.839996,
#        112.900002, 112.82    , 111.400002, 110.839996, 110.599998,
#        112.440002, 109.860001, 108.559998, 106.5     , 106.660004,
#        104.879997, 102.360001, 102.980003, 100.440002, 102.260002,
#        105.059998, 104.199997, 102.059998,  99.449997, 101.220001,
#         98.699997, 102.480003, 100.919998, 101.839996, 101.32    ,
#        103.239998, 105.139999, 104.360001, 101.860001, 100.919998,
#        103.419998, 103.260002, 102.699997, 101.519997, 101.      ,
#        103.639999, 102.400002, 104.879997, 104.239998, 106.440002,
#        107.080002, 108.940002, 111.120003, 110.540001, 112.360001,
#        111.040001, 112.519997, 111.5     , 111.739998, 110.699997,
#        110.620003, 109.599998, 111.559998, 111.160004, 111.459999,
#        110.82    , 110.199997, 109.660004, 109.760002, 105.559998,
#        107.839996, 106.760002, 107.18    ])

# %%
plt.plot(real_stock_price, color = 'black', label = 'Actual Stock Price')
plt.plot(predicted_stock_price, color = 'green', label = 'Predicted Stock Price')
plt.title('Anadarko P. Stock Price Prediction')
plt.xlabel('Time (Days)')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Stock price prediction very near the actual results also predicted stock follow the actual stock direction.
#
# ---
# ---
