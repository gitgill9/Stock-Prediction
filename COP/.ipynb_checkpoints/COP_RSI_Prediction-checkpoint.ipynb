# %%
#import all the basic libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the dataset in to dataframe
df = pd.read_csv('data/COP.csv')

# %%
# Visually scan the data
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2016-05-09  42.310001  42.490002  41.119999  41.650002  36.638519
# 1  2016-05-10  41.619999  42.889999  41.580002  42.869999  37.711727
# 2  2016-05-11  42.869999  44.430000  42.310001  43.680000  38.424255
# 3  2016-05-12  44.049999  44.689999  43.049999  43.730000  38.468250
# 4  2016-05-13  43.369999  43.919998  42.840000  43.020000  37.843678
#
#       Volume       OBV  12_day_EMA  30_day_EMA  MACD    Change      Gain  \
# 0  7049800.0         0         NaN         NaN   NaN       NaN       NaN
# 1  7969500.0   7969500         NaN         NaN   NaN  1.219997  1.219997
# 2  8913000.0  16882500         NaN         NaN   NaN  0.810001  0.000000
# 3  8380800.0  25263300         NaN         NaN   NaN  0.050000  0.789024
# 4  6203300.0  19060000         NaN         NaN   NaN -0.710000  0.000000
#
#    Loss   Avg Gain  Avg Loss  RS  RSI
# 0    NaN       NaN       NaN NaN  NaN
# 1   0.00       NaN       NaN NaN  NaN
# 2   0.00       NaN       NaN NaN  NaN
# 3   0.00       NaN       NaN NaN  NaN
# 4   0.71       NaN       NaN NaN  NaN

# %%
#Rows and columns in the dataframe
df.shape
# Out:
# (1267, 18)

# %% [markdown]
# ## EDA

# %%
#Check for null values in the columns
df.isna().sum()
# Out:
# Date           8
# Open           8
# High           8
# Low            8
# Close          8
# Adj Close      8
# Volume         8
# OBV            0
# 12_day_EMA    11
# 30_day_EMA    29
# MACD          29
# Change         1
# Gain           1
# Loss           1
# Avg Gain      14
# Avg Loss      14
# RS            14
# RSI           14
# dtype: int64

# %% [markdown]
# The null values in the dataframe exist as some columns required previous days information. We will drop all the rows with null values.

# %%
#Drop the null values rows
df = df.dropna()

# %%
df.head()
# Out:
#           Date       Open       High        Low      Close  Adj Close  \
# 29  2016-06-20  45.000000  45.360001  44.570000  44.689999  39.538513
# 30  2016-06-21  44.580002  45.080002  44.250000  44.799999  39.635838
# 31  2016-06-22  45.119999  45.180000  43.910000  43.990002  38.919205
# 32  2016-06-23  44.599998  45.639999  44.270000  45.630001  40.370159
# 33  2016-06-24  43.320000  44.419998  42.919998  43.169998  38.193726
#
#         Volume       OBV  12_day_EMA  30_day_EMA      MACD    Change  \
# 29   8374600.0  10732100   44.976667   44.201667  0.775000  0.539997
# 30   6783300.0  17515400   45.028333   44.306667  0.721666  0.110000
# 31   8649100.0   8866300   44.900834   44.344000  0.556833 -0.809997
# 32   7714800.0  16581100   44.741667   44.409000  0.332666  1.639999
# 33  13630200.0   2950900   44.381667   44.390334 -0.008667 -2.460003
#
#         Gain     Loss   Avg Gain  Avg Loss        RS        RSI
# 29  0.846177  0.000000  0.291747  0.358571  0.813637  44.862171
# 30  0.512596  0.000000  0.320805  0.358571  0.894674  47.220475
# 31  0.000000  0.809997  0.320805  0.416428  0.770372  43.514684
# 32  1.749306  0.000000  0.438200  0.402143  1.089663  52.145384
# 33  0.000000  2.460003  0.408561  0.577857  0.707027  41.418621

# %%
df.isna().sum()
# Out:
# Date          0
# Open          0
# High          0
# Low           0
# Close         0
# Adj Close     0
# Volume        0
# OBV           0
# 12_day_EMA    0
# 30_day_EMA    0
# MACD          0
# Change        0
# Gain          0
# Loss          0
# Avg Gain      0
# Avg Loss      0
# RS            0
# RSI           0
# dtype: int64

# %% [markdown]
# Now our dataframe does not include any null values.

# %% [markdown]
# We will filter out the columns we need for modeling by creating a new dataframe.

# %%
# Final Dataframe
df_final = df[['Close', 'Volume','OBV','MACD','RSI']]

df_final.head()
# Out:
#         Close      Volume       OBV      MACD        RSI
# 29  44.689999   8374600.0  10732100  0.775000  44.862171
# 30  44.799999   6783300.0  17515400  0.721666  47.220475
# 31  43.990002   8649100.0   8866300  0.556833  43.514684
# 32  45.630001   7714800.0  16581100  0.332666  52.145384
# 33  43.169998  13630200.0   2950900 -0.008667  41.418621

# %% [markdown]
# ---

# %% [markdown]
# ## Visualization

# %%
plt.figure(figsize = (10,7))
plt.plot( df["Close"])
plt.xlabel("Time (Days)")
plt.ylabel("Close Price")
plt.title("COP Close Price")
plt.show()

# %%
plt.figure(figsize= (10,7))
plt.plot( df['OBV'], color = 'Orange')
plt.xlabel("Time (Days)")
plt.ylabel("Volume")
plt.title("COP OBV")
plt.show()

# %%
plt.figure(figsize= (10,7))
plt.plot( df['MACD'], color = 'Purple')
plt.xlabel("Time (Days)")
plt.ylabel("MACD")
plt.title("COP MACD")
plt.show()

# %%
plt.figure(figsize= (10,7))
plt.plot( df['RSI'], color = 'Green')
plt.xlabel("Time (Days)")
plt.ylabel("RSI")
plt.title("COP RSI")
plt.show()

# %% [markdown]
# We can see every indicator behave differently to price change. We can deduce that their is no correlation thee. Let's check its correlation by plotting each against one another.

# %%
sns.pairplot(df_final)

# %% [markdown]
# ### Correlation Matrix

# %%
# Compute the correlation matrix
corr = df_final.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap 
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,annot= True,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# From the above visuals it is clear that there is hardly any correlation between the technical indicators.

# %% [markdown]
# ---

# %% [markdown]
# ## **LSTM Modeling**

# %% [markdown]
# ### Set the Training set

# %%
#Selecting first 1000 values to train the dataset
training_set = df_final.iloc[:1000].values

# %%
training_set
# Out:
# array([[4.46899990e+01, 8.37460000e+06, 1.07321000e+07, 7.74999733e-01,
#         4.48621714e+01],
#        [4.47999990e+01, 6.78330000e+06, 1.75154000e+07, 7.21666417e-01,
#         4.72204752e+01],
#        [4.39900020e+01, 8.64910000e+06, 8.86630000e+06, 5.56833150e-01,
#         4.35146842e+01],
#        ...,
#        [4.85900000e+01, 1.15788000e+07, 5.73909000e+07, 2.09283320e+00,
#         8.21109603e+01],
#        [5.03100010e+01, 1.02422000e+07, 6.76331000e+07, 2.13216642e+00,
#         8.05122176e+01],
#        [4.86300010e+01, 8.20360000e+06, 5.94295000e+07, 2.15866645e+00,
#         7.80839990e+01]])

# %% [markdown]
# ### Feature Scaling

# %% [markdown]
# **Scaling the dataset:** LSTM is highly sensitive in nature. We will need to scale it. We will use Standard Scaler for this dataset, as MinMax scaler is inappropriate for stock prices.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
training_set_scaled = scaler.fit_transform(training_set)

# %%
training_set_scaled
# Out:
# array([[-0.95134048,  0.38729293, -0.58315998,  0.33091376, -0.69245041],
#        [-0.94118065, -0.15438069, -0.48806238,  0.30854336, -0.54670546],
#        [-1.01599365,  0.48073189, -0.60931732,  0.23940484, -0.77572613],
#        ...,
#        [-0.59112832,  1.47799277,  0.07096706,  0.88367266,  1.60955275],
#        [-0.43226547,  1.02301823,  0.21455626,  0.90017079,  1.51074925],
#        [-0.58743375,  0.32908506,  0.09954695,  0.9112861 ,  1.36068352]])

# %% [markdown]
# **We will use set of 60 values as sequence to predict the final outcome.**  Our X_train will have 940 sequences each with length of 60. y_train will have 940 values of stock prices corresponding to each sequence

# %%
X_train = []
y_train = []
for i in range(60, 1000):
    X_train.append(training_set_scaled[i-60:i, 4])  # Selecting indicator/price sequence 
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
X_train.shape
# Out:
# (940, 60, 1)

# %%
y_train.shape
# Out:
# (940,)

# %%
#import models using Keras library
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
#Initialize the model
model = Sequential()

#Set the inputs for first layer
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))   # use of dropout to prevent any overfitting

# Add  three hidden layers
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units = 50))
model.add(Dropout(0.2))

# Get the output as single value
model.add(Dense(units = 1))

# set optimizer and loss metrics
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

#Fit the model 
model.fit(X_train, y_train, epochs = 50, batch_size = 32)
# Out:
# Epoch 1/50
# 30/30 [==============================] - 21s 59ms/step - loss: 0.9106 0s - loss: 0.
# Epoch 2/50
# 30/30 [==============================] - 2s 60ms/step - loss: 0.8281
# Epoch 3/50
# 30/30 [==============================] - 2s 58ms/step - loss: 0.7784
# Epoch 4/50
# 30/30 [==============================] - 2s 59ms/step - loss: 0.7926
# Epoch 5/50
# 30/30 [==============================] - 2s 58ms/step - loss: 0.7780
# Epoch 6/50
# 30/30 [==============================] - 2s 62ms/step - loss: 0.6874
# Epoch 7/50
# 30/30 [==============================] - 2s 59ms/step - loss: 0.5757: 0s -
# Epoch 8/50
# 30/30 [==============================] - 2s 58ms/step - loss: 0.4707
# Epoch 9/50
# 30/30 [==============================] - 2s 59ms/step - loss: 0.3202
# Epoch 10/50
# 30/30 [==============================] - 2s 58ms/step - loss: 0.2958
# Epoch 11/50
# 30/30 [==============================] - 2s 62ms/step - loss: 0.2410
# Epoch 12/50
# 30/30 [==============================] - 2s 62ms/step - loss: 0.2143
# Epoch 13/50
# 30/30 [==============================] - 2s 59ms/step - loss: 0.1428
# Epoch 14/50
# 30/30 [==============================] - 2s 59ms/step - loss: 0.1062
# Epoch 15/50
# 30/30 [==============================] - 2s 59ms/step - loss: 0.1135
# Epoch 16/50
# 30/30 [==============================] - 2s 59ms/step - loss: 0.1079: 0s - lo
# Epoch 17/50
# 30/30 [==============================] - 2s 58ms/step - loss: 0.0905
# Epoch 18/50
# 30/30 [==============================] - 2s 62ms/step - loss: 0.0693
# Epoch 19/50
# 30/30 [==============================] - 2s 60ms/step - loss: 0.0634
# Epoch 20/50
# 30/30 [==============================] - 2s 67ms/step - loss: 0.0584
# Epoch 21/50
# 30/30 [==============================] - 2s 65ms/step - loss: 0.0519
# Epoch 22/50
# 30/30 [==============================] - 2s 71ms/step - loss: 0.0545
# Epoch 23/50
# 30/30 [==============================] - 2s 67ms/step - loss: 0.0498
# Epoch 24/50
# 30/30 [==============================] - 2s 67ms/step - loss: 0.0502
# Epoch 25/50
# 30/30 [==============================] - 2s 66ms/step - loss: 0.0504
# Epoch 26/50
# 30/30 [==============================] - 2s 66ms/step - loss: 0.0411
# Epoch 27/50
# 30/30 [==============================] - 2s 69ms/step - loss: 0.0374
# Epoch 28/50
# 30/30 [==============================] - 2s 67ms/step - loss: 0.0414:
# Epoch 29/50
# 30/30 [==============================] - 2s 67ms/step - loss: 0.0404
# Epoch 30/50
# 30/30 [==============================] - 2s 67ms/step - loss: 0.0370
# Epoch 31/50
# 30/30 [==============================] - 2s 65ms/step - loss: 0.0440
# Epoch 32/50
# 30/30 [==============================] - 2s 68ms/step - loss: 0.0386
# Epoch 33/50
# 30/30 [==============================] - 2s 66ms/step - loss: 0.0320
# Epoch 34/50
# 30/30 [==============================] - 2s 68ms/step - loss: 0.0339
# Epoch 35/50
# 30/30 [==============================] - 2s 69ms/step - loss: 0.0322
# Epoch 36/50
# 30/30 [==============================] - 2s 71ms/step - loss: 0.0307
# Epoch 37/50
# 30/30 [==============================] - 2s 74ms/step - loss: 0.0385
# Epoch 38/50
# 30/30 [==============================] - 2s 71ms/step - loss: 0.0352
# Epoch 39/50
# 30/30 [==============================] - 2s 69ms/step - loss: 0.0289
# Epoch 40/50
# 30/30 [==============================] - 2s 71ms/step - loss: 0.0281
# Epoch 41/50
# 30/30 [==============================] - 2s 70ms/step - loss: 0.0293
# Epoch 42/50
# 30/30 [==============================] - 2s 68ms/step - loss: 0.0306
# Epoch 43/50
# 30/30 [==============================] - 2s 74ms/step - loss: 0.0336
# Epoch 44/50
# 30/30 [==============================] - 2s 69ms/step - loss: 0.0279
# Epoch 45/50
# 30/30 [==============================] - 2s 69ms/step - loss: 0.0319
# Epoch 46/50
# 30/30 [==============================] - 2s 68ms/step - loss: 0.0303
# Epoch 47/50
# 30/30 [==============================] - 2s 71ms/step - loss: 0.0329
# Epoch 48/50
# 30/30 [==============================] - 2s 74ms/step - loss: 0.0374
# Epoch 49/50
# 30/30 [==============================] - 2s 67ms/step - loss: 0.0264
# Epoch 50/50
# 30/30 [==============================] - 2s 69ms/step - loss: 0.0272

# %%
#Standard scalar for test set
scaler_test = StandardScaler()
test_set_scaled = scaler_test.fit_transform(df_final['RSI'].values.reshape(-1,1))

# %%
#set the test set

dataset_total = pd.concat((df_final['RSI'].iloc[:1000], df_final['RSI'][1000:]), axis = 0)
inputs = dataset_total[len(dataset_total) - len(df_final['RSI'][1000:]) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = scaler_test.transform(inputs)
X_test = []
for i in range(60, 291):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = model.predict(X_test)
predicted_stock_price = scaler_test.inverse_transform(predicted_stock_price)

# %%
predicted_stock_price
# Out:
# array([[49.38458 ],
#        [50.682827],
#        [52.066128],
#        [54.094063],
#        [56.66003 ],
#        [61.221176],
#        [72.314095],
#        [75.22984 ],
#        [75.53279 ],
#        [75.10733 ],
#        [73.97444 ],
#        [72.860176],
#        [71.652145],
#        [70.574326],
#        [70.03497 ],
#        [70.10774 ],
#        [70.59709 ],
#        [71.43707 ],
#        [72.00209 ],
#        [72.19445 ],
#        [72.173325],
#        [71.80967 ],
#        [71.34123 ],
#        [70.97827 ],
#        [70.841774],
#        [70.75911 ],
#        [70.85455 ],
#        [71.082886],
#        [71.454704],
#        [71.84629 ],
#        [72.247604],
#        [72.61474 ],
#        [72.92828 ],
#        [73.10332 ],
#        [73.36002 ],
#        [73.47016 ],
#        [73.30629 ],
#        [72.81762 ],
#        [72.13282 ],
#        [71.045425],
#        [69.96705 ],
#        [68.94749 ],
#        [67.603615],
#        [66.02711 ],
#        [63.887768],
#        [61.231995],
#        [57.89606 ],
#        [56.503616],
#        [58.227985],
#        [60.47261 ],
#        [64.84604 ],
#        [68.328   ],
#        [66.54129 ],
#        [65.59119 ],
#        [67.498825],
#        [70.995316],
#        [72.16506 ],
#        [76.92294 ],
#        [78.303406],
#        [78.457664],
#        [78.164986],
#        [77.62767 ],
#        [77.15928 ],
#        [77.12428 ],
#        [77.31963 ],
#        [78.439766],
#        [79.64513 ],
#        [80.326   ],
#        [80.12201 ],
#        [79.55142 ],
#        [79.360916],
#        [79.199905],
#        [78.889496],
#        [78.12232 ],
#        [74.97959 ],
#        [74.59973 ],
#        [74.561676],
#        [73.62513 ],
#        [72.74739 ],
#        [70.38559 ],
#        [68.6942  ],
#        [67.026276],
#        [66.14618 ],
#        [65.57847 ],
#        [65.39252 ],
#        [65.599686],
#        [66.060776],
#        [66.802414],
#        [67.67568 ],
#        [68.85863 ],
#        [69.99688 ],
#        [70.784706],
#        [71.201965],
#        [71.34655 ],
#        [71.167145],
#        [70.94757 ],
#        [70.32311 ],
#        [69.50518 ],
#        [68.36227 ],
#        [66.963974],
#        [65.23658 ],
#        [63.20557 ],
#        [60.921494],
#        [58.432816],
#        [55.870983],
#        [53.333286],
#        [50.93986 ],
#        [49.054527],
#        [48.0301  ],
#        [47.55044 ],
#        [47.463524],
#        [47.362072],
#        [47.246048],
#        [47.104362],
#        [46.90722 ],
#        [46.59162 ],
#        [46.271008],
#        [45.918636],
#        [45.65065 ],
#        [45.41372 ],
#        [45.30092 ],
#        [45.206673],
#        [45.127575],
#        [45.03533 ],
#        [45.074013],
#        [45.113163],
#        [45.176346],
#        [45.11192 ],
#        [45.04795 ],
#        [45.20828 ],
#        [45.37763 ],
#        [45.450832],
#        [45.427616],
#        [45.40787 ],
#        [45.22177 ],
#        [45.057568],
#        [57.054783],
#        [54.555836],
#        [56.706726],
#        [55.671726],
#        [54.89793 ],
#        [54.374584],
#        [54.037704],
#        [54.26852 ],
#        [54.61365 ],
#        [55.011375],
#        [55.4286  ],
#        [55.92623 ],
#        [56.37903 ],
#        [56.700794],
#        [56.712105],
#        [56.85793 ],
#        [56.716473],
#        [56.3899  ],
#        [56.0154  ],
#        [55.496532],
#        [54.91807 ],
#        [54.235603],
#        [53.440193],
#        [52.557144],
#        [51.538906],
#        [50.381317],
#        [49.09236 ],
#        [47.722656],
#        [46.60291 ],
#        [46.448124],
#        [46.9618  ],
#        [45.38428 ],
#        [44.232708],
#        [43.913315],
#        [43.93972 ],
#        [44.236046],
#        [44.72688 ],
#        [45.38648 ],
#        [46.143276],
#        [47.0908  ],
#        [48.33893 ],
#        [50.51408 ],
#        [52.439026],
#        [52.997616],
#        [52.779472],
#        [52.3176  ],
#        [51.929966],
#        [51.59139 ],
#        [51.441612],
#        [51.322773],
#        [51.00191 ],
#        [50.66085 ],
#        [50.279987],
#        [49.78138 ],
#        [49.16233 ],
#        [48.96531 ],
#        [49.100224],
#        [49.18056 ],
#        [49.21418 ],
#        [49.135994],
#        [49.17525 ],
#        [49.336502],
#        [49.469624],
#        [49.734154],
#        [49.973473],
#        [50.301865],
#        [50.733143],
#        [51.575867],
#        [55.543762],
#        [54.701756],
#        [53.767017],
#        [54.00559 ],
#        [54.496037],
#        [55.05847 ],
#        [55.930874],
#        [56.880226],
#        [57.037903],
#        [57.03767 ],
#        [57.025734],
#        [56.916634],
#        [56.65052 ],
#        [56.14859 ],
#        [55.286102],
#        [53.89252 ],
#        [52.039055],
#        [50.018208],
#        [48.17114 ],
#        [47.065334],
#        [47.964035],
#        [48.73665 ],
#        [51.430893],
#        [51.412758],
#        [51.74156 ],
#        [52.30927 ],
#        [52.231018]], dtype=float32)

# %%
real_stock_price = df['Close'][1000:].values

# %%
real_stock_price
# Out:
# array([45.91    , 42.119999, 43.73    , 43.349998, 45.110001, 44.02    ,
#        44.450001, 43.700001, 43.560001, 43.810001, 40.990002, 42.060001,
#        40.349998, 41.299999, 42.02    , 40.740002, 41.779999, 41.630001,
#        40.639999, 41.040001, 38.349998, 39.689999, 39.66    , 41.310001,
#        41.619999, 41.59    , 39.959999, 39.330002, 41.66    , 40.889999,
#        40.459999, 40.279999, 39.77    , 38.959999, 39.939999, 37.639999,
#        37.389999, 36.709999, 37.639999, 38.02    , 38.049999, 38.299999,
#        39.639999, 39.709999, 41.66    , 40.630001, 40.82    , 40.700001,
#        40.330002, 39.650002, 38.77    , 38.16    , 38.869999, 38.849998,
#        37.560001, 38.150002, 38.380001, 37.889999, 37.16    , 36.380001,
#        35.990002, 35.860001, 34.060001, 34.459999, 32.919998, 33.110001,
#        33.52    , 33.799999, 35.080002, 36.09    , 35.869999, 34.360001,
#        34.299999, 32.919998, 33.599998, 33.700001, 33.709999, 32.459999,
#        32.84    , 32.43    , 33.07    , 34.279999, 33.299999, 34.330002,
#        35.529999, 35.130001, 35.59    , 34.880001, 34.529999, 35.400002,
#        33.77    , 32.700001, 32.580002, 30.639999, 31.91    , 32.540001,
#        30.32    , 30.26    , 28.790001, 29.16    , 28.620001, 30.23    ,
#        29.309999, 30.379999, 30.120001, 29.190001, 33.380001, 35.529999,
#        35.279999, 34.009998, 35.360001, 38.080002, 38.849998, 39.18    ,
#        39.470001, 39.650002, 42.709999, 44.41    , 43.630001, 42.779999,
#        39.560001, 39.27    , 39.970001, 41.200001, 44.27    , 42.82    ,
#        42.68    , 42.700001, 44.      , 43.48    , 42.32    , 42.799999,
#        42.32    , 41.970001, 40.98    , 40.240002, 39.029999, 40.080002,
#        39.490002, 39.299999, 39.07    , 40.009998, 39.990002, 39.57    ,
#        41.84    , 43.509998, 44.700001, 44.700001, 45.360001, 47.419998,
#        47.029999, 47.869999, 45.119999, 46.      , 45.360001, 43.189999,
#        42.689999, 42.580002, 41.68    , 40.650002, 41.110001, 40.029999,
#        40.709999, 40.970001, 43.209999, 44.009998, 44.419998, 46.779999,
#        46.880001, 47.25    , 46.439999, 47.16    , 48.849998, 49.360001,
#        47.689999, 48.419998, 50.880001, 52.099998, 54.669998, 53.029999,
#        52.009998, 52.610001, 52.279999, 53.66    , 55.619999, 58.34    ,
#        58.779999, 57.900002, 59.419998, 59.830002, 59.189999, 58.16    ,
#        56.580002, 56.830002, 53.380001, 52.599998, 52.240002, 51.709999,
#        53.209999, 53.57    , 55.040001, 53.84    , 53.43    , 52.970001,
#        54.02    , 52.209999, 52.580002, 52.380001, 51.240002, 51.23    ,
#        50.860001, 50.790001, 52.689999, 51.900002, 51.09    , 50.889999,
#        48.650002, 50.040001, 49.459999, 49.720001, 50.25    , 51.299999,
#        53.040001, 53.130001, 51.139999, 52.740002, 52.57    , 55.439999,
#        55.700001, 57.099998])

# %%
plt.plot(real_stock_price, color = 'black', label = 'Actual Stock Price')
plt.plot(predicted_stock_price, color = 'green', label = 'Predicted Stock Price')
plt.title('CONOCO PHILIPS Stock Price Prediction')
plt.xlabel('Time (Days)')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Stock price prediction somewhat close to the actual results after 100 days but before that our model predicting prices more than double of actual prices.
#
# ---
# ---
